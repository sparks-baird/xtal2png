# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/sparks-baird/xtal2png/blob/main/notebooks/pillow_grayscale_example.ipynb)

# %% [markdown]
# ## Installing Pillow

# %% [markdown]
# This notebook was created as part of a webinar. You can check the Webinar here - https://www.youtube.com/watch?v=Gblg8FMUn9k
#
# If you need any help, feel free to contact me on Slack. My slack id is **avinashss**

# %%
import PIL
print(PIL.PILLOW_VERSION)
# Out:
# 7.1.2
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: PILLOW_VERSION is deprecated and will be removed in a future release. Use __version__ instead.

# %%
from PIL import Image
import numpy as np
import pandas as pd

# %%
import requests
url = "https://www.entoin.com/images/chara50.jpg"
img = Image.open(requests.get(url, stream=True).raw)

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1100x619 at 0x7FA7EBD74310>

# %%
img.convert("L")
# Out:
# <PIL.Image.Image image mode=L size=1100x619 at 0x7FA7EBD02A90>

# %%
arr = np.asarray(img.convert("L"))
print(arr.shape)
arr
# Out:
# (619, 1100)
# array([[252, 252, 252, ..., 232, 232, 232],
#        [253, 253, 253, ..., 229, 229, 229],
#        [249, 249, 249, ..., 227, 227, 227],
#        ...,
#        [111, 111, 111, ..., 247, 236, 223],
#        [111, 111, 111, ..., 247, 236, 223],
#        [111, 111, 111, ..., 247, 236, 223]], dtype=uint8)

# %%
pd.DataFrame(arr.reshape(-1,1)).describe()
# Out:
#                    0
# count  680900.000000
# mean      184.128725
# std        52.320561
# min         4.000000
# 25%       144.000000
# 50%       201.000000
# 75%       224.000000
# max       255.000000

# %%
arr2 = np.asarray(img.convert("L").convert("RGB"))
print(arr2.shape)
# Out:
# (619, 1100, 3)

# %%
arr2[0,0]
# Out:
# array([252, 252, 252], dtype=uint8)
